# %%
#Anaconda ile kurulmayan Python kütüphanelerinin kurulumu için:
#pip install "kütüphane ismi"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import csv
import requests
from bs4 import BeautifulSoup
# Create empty lists to store each data column (feature)
date=[]
price = []
location= []
area = []
owner = []
room = []
seller = []
age = []
title = []
floor = []

r = requests.get("https://www.hurriyetemlak.com/konut-kiralik")
#print(r)
soup = BeautifulSoup(r.text,'html.parser')
#print(soup)
results = soup.find_all("a", attrs={'class':'overlay-link'})
#print(results)
#
for tag in results :
    price.append(tag.get('data-price'))
    area.append(tag.get('data-meter'))
    owner.append(tag.get('data-owner'))
    room.append(tag.get('data-room'))
    seller.append(tag.get('data-seller-type'))
    age.append(tag.get('data-age'))
    title.append(tag.get('title'))        
    floor.append(tag.get('data-floor'))
    location.append(tag.get("href"))
    date.append(tag.get("data-date"))
       
records={"location":location,"floor":floor,"title": title, "price": price, "age":age, "area-m2": area, "owner":owner, "room": room, "seller": seller,"date":date}

df = pd.DataFrame(records)
print (df)
df.to_csv("hurriyetemlak_dirty.csv")
# Out:
#                                              location         floor  \
# 0       /ankara-cankaya-sancak-kiralik/bina/13391-424        3. Kat
# 1   /ankara-cankaya-bahcelievler-kiralik/daire/709...        2. Kat
# 2   /istanbul-sariyer-istinye-kiralik/daire/89328-...    Bahçe Katı
# 3   /istanbul-sisli-gulbahar-kiralik/daire/33012-4954        2. Kat
# 4   /istanbul-sisli-fulya-kiralik/residence/28284-...   21 ve üzeri
# 5       /izmir-konak-altintas-kiralik/daire/9709-3800        2. Kat
# 6        /ankara-cankaya-ata-kiralik/daire/3240-11367        1. Kat
# 7   /istanbul-kadikoy-fenerbahce-kiralik/daire/269...        3. Kat
# 8   /istanbul-besiktas-cihannuma-kiralik/daire/325...        4. Kat
# 9   /istanbul-besiktas-etiler-kiralik/residence/33...        3. Kat
# 10  /istanbul-kadikoy-fenerbahce-kiralik/daire/358...        7. Kat
# 11  /istanbul-sisli-esentepe-kiralik/residence/336...       19. Kat
# 12  /istanbul-zeytinburnu-maltepe-kiralik/residenc...        4. Kat
# 13  /istanbul-sariyer-istinye-kiralik/residence/96...    Bahçe Katı
# 14  /istanbul-bahcelievler-siyavuspasa-kiralik/dai...  Yüksek Giriş
# 15  /istanbul-beykoz-acarlar-kiralik/villa/60784-2317    Bahçe Katı
# 16  /istanbul-fatih-sehremini-kiralik/daire/23051-...        2. Kat
# 17  /istanbul-kagithane-emniyetevleri-kiralik/resi...       11. Kat
# 18   /ankara-cankaya-ayranci-kiralik/daire/11065-1259  Yüksek Giriş
# 19  /ankara-cankaya-osman-temiz-kiralik/daire/4664...       11. Kat
# 20      /ankara-cankaya-sancak-kiralik/bina/13391-424          None
# 21  /ankara-cankaya-bahcelievler-kiralik/daire/709...          None
# 22  /istanbul-sariyer-istinye-kiralik/daire/89328-...          None
# 23  /istanbul-sisli-gulbahar-kiralik/daire/33012-4954          None
# 24  /istanbul-sisli-fulya-kiralik/residence/28284-...          None
# 25      /izmir-konak-altintas-kiralik/daire/9709-3800          None
# 26       /ankara-cankaya-ata-kiralik/daire/3240-11367          None
# 27  /istanbul-kadikoy-fenerbahce-kiralik/daire/269...          None
# 28  /istanbul-besiktas-cihannuma-kiralik/daire/325...          None
# 29  /istanbul-besiktas-etiler-kiralik/residence/33...          None
# 30  /istanbul-kadikoy-fenerbahce-kiralik/daire/358...          None
# 31  /istanbul-sisli-esentepe-kiralik/residence/336...          None
# 32  /istanbul-zeytinburnu-maltepe-kiralik/residenc...          None
# 33  /istanbul-sariyer-istinye-kiralik/residence/96...          None
# 34  /istanbul-bahcelievler-siyavuspasa-kiralik/dai...          None
# 35  /istanbul-beykoz-acarlar-kiralik/villa/60784-2317          None
# 36  /istanbul-fatih-sehremini-kiralik/daire/23051-...          None
# 37  /istanbul-kagithane-emniyetevleri-kiralik/resi...          None
# 38   /ankara-cankaya-ayranci-kiralik/daire/11065-1259          None
# 39  /ankara-cankaya-osman-temiz-kiralik/daire/4664...          None
#
#                                                 title   price   age area-m2  \
# 0                  SANCAKTA KİRALIK ARA KAT 3+1 DAİRE   1.400    17     160
# 1   TUTKU\u0027dan BAHÇELİEVLER\u0027de KATTA 3+1 ...   1.700    27     130
# 2   İSTİNYE SEBA AKDAĞ DREAM KİRALIK 5+1 KEYİFLİ B...  25.000     5     330
# 3   Şişli Gülbağ yokuşsuz 3+1 120m2 masrafsız \u00...   2.100    18     120
# 4   Selenium Twins Residence\u0027de full eşyalı 3...  35.000    10     300
# 5   İnönü Caddesinin Bir Alt Sokağında Köşe Sıfır ...   1.800     0     140
# 6   BORSEM DİKMEN\u0027DEN ÖVEÇLER KABİL CADDESİ Y...   1.100    15     125
# 7    Point Emlak FENERBAHÇE\u0027DE ORDU EVİNİN YA...   8.000     0     225
# 8   BEŞİKTAŞ BULVARDA 3+1 SIFIR YOKUŞ ARA KAT TEMİ...   2.650    30     100
# 9   ETİLER KİRALIK MAYA RESİDENCE 2+1 AÇIK MUTFAK ...  10.000    16     166
# 10  DALYAN\u0027NIN EN GÜZEL SOKAĞINDA ANKASTRELİ ...   3.500    25     175
# 11                    İSTANBLOOM RESİDENCE DA LÜX 3+1  14.500     4     228
# 12  İnistanbul Topkapı\u0027da Kiralık Eşyalı 1+1 ...   2.300     0      52
# 13  İSTİNYEPARK TA PENTHOUSE TEKKAT DÜZ BAHCE KATİ...  50.000     8     500
# 14  BAHÇELİEVLER MERKEZDE YENİ BİNADA ASANSÖRLÜ AR...   1.150     4      65
# 15  ACARKENT MARKAVİLLA\u0027dan ACARKENT\u0027te ...   9.250     5     400
# 16  Fatih Çapada Kiralık 2+1 Salon Daire Emlak Cen...   1.700    29     110
# 17  LEVENT REZİDANS\u0027TA OTURUM BAŞLIYOR SIFIR ...   2.150     0      75
# 18  AYRANCI UÇARL\u0027DA,3+1,YÜKSEK GİRİŞ,ÇOK TEM...   1.250    42     120
# 19  REŞADİYE\u0027DEN DİKMEN OSMAN TEMİZ MAH.SİTE ...   1.200    20     120
# 20                 SANCAKTA KİRALIK ARA KAT 3+1 DAİRE    None  None    None
# 21  TUTKU'dan BAHÇELİEVLER'de KATTA 3+1 BAKIMLI DAİRE    None  None    None
# 22  İSTİNYE SEBA AKDAĞ DREAM KİRALIK 5+1 KEYİFLİ B...    None  None    None
# 23  Şişli Gülbağ yokuşsuz 3+1 120m2 masrafsız 'AKD...    None  None    None
# 24  Selenium Twins Residence'de full eşyalı 300m2 ...    None  None    None
# 25  İnönü Caddesinin Bir Alt Sokağında Köşe Sıfır ...    None  None    None
# 26  BORSEM DİKMEN'DEN ÖVEÇLER KABİL CADDESİ YAKINI...    None  None    None
# 27   Point Emlak FENERBAHÇE'DE ORDU EVİNİN YANINDA...    None  None    None
# 28  BEŞİKTAŞ BULVARDA 3+1 SIFIR YOKUŞ ARA KAT TEMİ...    None  None    None
# 29  ETİLER KİRALIK MAYA RESİDENCE 2+1 AÇIK MUTFAK ...    None  None    None
# 30  DALYAN'NIN EN GÜZEL SOKAĞINDA ANKASTRELİ GENİŞ...    None  None    None
# 31                    İSTANBLOOM RESİDENCE DA LÜX 3+1    None  None    None
# 32  İnistanbul Topkapı'da Kiralık Eşyalı 1+1 Daire...    None  None    None
# 33  İSTİNYEPARK TA PENTHOUSE TEKKAT DÜZ BAHCE KATİ...    None  None    None
# 34  BAHÇELİEVLER MERKEZDE YENİ BİNADA ASANSÖRLÜ AR...    None  None    None
# 35  ACARKENT MARKAVİLLA'dan ACARKENT'te KİRALIK BA...    None  None    None
# 36  Fatih Çapada Kiralık 2+1 Salon Daire Emlak Cen...    None  None    None
# 37  LEVENT REZİDANS'TA OTURUM BAŞLIYOR SIFIR ARAKA...    None  None    None
# 38  AYRANCI UÇARL'DA,3+1,YÜKSEK GİRİŞ,ÇOK TEMİZ AR...    None  None    None
# 39  REŞADİYE'DEN DİKMEN OSMAN TEMİZ MAH.SİTE İÇERİ...    None  None    None
#
#          owner  room    seller        date
# 0   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 1   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 2   Emlakçıdan   5+1  Kurumsal  20.01.2019
# 3   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 4   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 5   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 6   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 7   Emlakçıdan   4+1  Kurumsal  20.01.2019
# 8   Emlakçıdan   3+1  Kurumsal  20.01.2019
# 9   Emlakçıdan   2+1  Kurumsal  20.01.2019
# 10  Emlakçıdan   4+1  Kurumsal  20.01.2019
# 11  Emlakçıdan   3+1  Kurumsal  20.01.2019
# 12  Emlakçıdan   1+1  Kurumsal  20.01.2019
# 13  Emlakçıdan   6+1  Kurumsal  20.01.2019
# 14  Emlakçıdan   1+1  Kurumsal  20.01.2019
# 15  Emlakçıdan   5+1  Kurumsal  20.01.2019
# 16  Emlakçıdan   2+1  Kurumsal  20.01.2019
# 17  Emlakçıdan   2+1  Kurumsal  20.01.2019
# 18  Emlakçıdan   3+1  Kurumsal  20.01.2019
# 19  Emlakçıdan   3+1  Kurumsal  20.01.2019
# 20        None  None  Bireysel        None
# 21        None  None  Bireysel        None
# 22        None  None  Kurumsal        None
# 23        None  None  Kurumsal        None
# 24        None  None  Kurumsal        None
# 25        None  None  Kurumsal        None
# 26        None  None  Kurumsal        None
# 27        None  None  Kurumsal        None
# 28        None  None  Bireysel        None
# 29        None  None  Kurumsal        None
# 30        None  None  Kurumsal        None
# 31        None  None  Kurumsal        None
# 32        None  None  Kurumsal        None
# 33        None  None  Kurumsal        None
# 34        None  None  Bireysel        None
# 35        None  None  Kurumsal        None
# 36        None  None  Kurumsal        None
# 37        None  None  Kurumsal        None
# 38        None  None  Kurumsal        None
# 39        None  None  Kurumsal        None

# %%
pwd
# Out:
# 'C:\\Users\\iince\\Documents\\GitHub\\Webscraping_IT Skills\\IT Jobs Popularity Analysis in UK'
